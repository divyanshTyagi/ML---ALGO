# %% [markdown]
# # We will use markov chains to reconstruct 'Apna Time Aenga' from the film gully boy

# %%
import numpy as np
import pandas as pd
np.random.seed(11)

# %%
# Getting the lyrics 
# !wget https://www.dropbox.com/s/b194dcosl4ri6eh/Apna%20Time%20Aayega.txt?dl=1
# Out:
# --2020-09-19 19:23:30--  https://www.dropbox.com/s/b194dcosl4ri6eh/Apna%20Time%20Aayega.txt?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.81.1, 2620:100:6031:1::a27d:5101
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.81.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/dl/b194dcosl4ri6eh/Apna%20Time%20Aayega.txt [following]
# --2020-09-19 19:23:31--  https://www.dropbox.com/s/dl/b194dcosl4ri6eh/Apna%20Time%20Aayega.txt
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc32fa9007ab5cc1bb0667ace129.dl.dropboxusercontent.com/cd/0/get/A_sJsbPODypkbvnimsp5LpQGVGALCmOAewEmW61Z_32_EUQnrl2l_4A5hLyZz5d1DwUBGITErltwlfpyXKs78bwGjHAnOFnFa12Ps6Kc84eDBw/file?dl=1# [following]
# --2020-09-19 19:23:32--  https://uc32fa9007ab5cc1bb0667ace129.dl.dropboxusercontent.com/cd/0/get/A_sJsbPODypkbvnimsp5LpQGVGALCmOAewEmW61Z_32_EUQnrl2l_4A5hLyZz5d1DwUBGITErltwlfpyXKs78bwGjHAnOFnFa12Ps6Kc84eDBw/file?dl=1
# Resolving uc32fa9007ab5cc1bb0667ace129.dl.dropboxusercontent.com (uc32fa9007ab5cc1bb0667ace129.dl.dropboxusercontent.com)... 162.125.81.15, 2620:100:6031:15::a27d:510f
# Connecting to uc32fa9007ab5cc1bb0667ace129.dl.dropboxusercontent.com (uc32fa9007ab5cc1bb0667ace129.dl.dropboxusercontent.com)|162.125.81.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1429 (1.4K) [application/binary]
# Saving to: ‘Apna Time Aayega.txt?dl=1.1’
#
# Apna Time Aayega.tx 100%[===================>]   1.40K  --.-KB/s    in 0s
#
# 2020-09-19 19:23:33 (170 MB/s) - ‘Apna Time Aayega.txt?dl=1.1’ saved [1429/1429]

# %%
text = ''
with open('Apna Time Aayega.txt','r') as file:
    text = file.read().lower()

# %%
print(len(text))
# Out:
# 1362

# %%
#Creating a transition table function 
def generateTable(text,k = 4):
    freq = {}
    e = k
    while(e < len(text)):
        pref = text[e-k:e]
        if(freq.get(pref) == None):
            freq[pref] = {}
            freq[pref].update({text[e]:1})
        else:
            if(freq[pref].get(text[e]) == None):
                freq[pref][text[e]] = 1
            else:
                freq[pref][text[e]]+=1
        e+=1

        for key in freq.keys():
            sum = float(np.array(list(freq[key].values())).sum()) 
            for key_ in freq[key].keys():
                freq[key][key_]/=sum
    return freq
    # A function to generate text
    
def trainMarkovChain(text,model,k,maxlen = 1000):
    T = model
    e = len(text)-k
    temp = text
    for i in range(maxlen):
        prev = temp[e:e+k]
        print(prev)
        if(T.get(prev) == None):
            temp+= ' '
        else:
          # we will use sampling to find out answer
            mostProbChar = np.random.choice(list(T[prev].keys()),p = list(T[prev].values()))
            temp += mostProbChar
        e+=1
    return temp

# %%
model = generateTable(text)
output = trainMarkovChain("apna",model,4,2000)
# Out:
# apna
# pna
# na t
# a ti
#  tim
# time
# ime
# me a
# e aa
#  aay
# aaye
# ayeg
# yega
# ega
#
# ga
#
# a
#
#
#
#
# t
#
# tu
#
# tu
# tu n
# u na
#  nan
# nang
# anga
# nga
# ga h
# a hi
#  hi
# hi t
# i to
#  to
# to a
# o aa
#  aay
# aaye
# ayeg
# yega
# ega
#
# ga
# a
# a
# ap
#
# apn
# apna
# pna
# na t
# a ti
#  tim
# time
# ime
# me a
# e aa
#  aay
# aaye
# ayeg
# yega
# ega
#
# ga
# a
# a
# ap
#
# apn
# apna
# pna
# na t
# a ti
#  tim
# time
# ime
# me a
# e aa
#  aay
# aaye
# ayeg
# yega
# ega
#
# ga
# a
# a
# ap
#
# apn
# apna
# pna
# na t
# a ti
#  tim
# time
# ime
# me a
# e aa
#  aay
# aaye
# ayeg
# yega
# ega
#
# ga
# a
# a
# ap
#
# apn
# apna
# pna
# na t
# a ti
#  tim
# time
# ime
# me a
# e aa
#  aay
# aaye
# ayeg
# yega
# ega
#
# ga
# a
# a
# ap
#
# apn
# apna
# pna
# na t
# a ti
#  tim
# time
# ime
# me a
# e aa
#  aay
# aaye
# ayeg
# yega
# ega
#
# ga
# a
# a
# ap
#
# apn
# apna
# pna
# na t
# a ti
#  tim
# time
# ime
# me a
# e aa
#  aay
# aaye
# ayeg
# yega
# ega
#
# ga
# k
# a
# ky
#
# kya
# kya
# ya g
# a gh
#  gha
# ghan
# hant
# anta
# nta
# ta l
# a le
#  lek
# leka
# ekar
# kar
# ar j
# r ja
#  jaa
# jaay
# aaye
# ayeg
# yega
# ega
#
# ga
# a
# a
# ap
#
# apn
# apna
# pna
# na t
# a ti
#  tim
# time
# ime
# me a
# e aa
#  aay
# aaye
# ayeg
# yega
# ega
#
# ga
# k
# a
# ky
#
# kya
# kya
# ya g
# a gh
#  gha
# ghan
# hant
# anta
# nta
# ta l
# a le
#  lek
# leka
# ekar
# kar
# ar j
# r ja
#  jaa
# jaay
# aaye
# ayeg
# yega
# ega
#
# ga
# k
# a
# ky
#
# kya
# kya
# ya g
# a gh
#  gha
# ghan
# hant
# anta
# nta
# ta l
# a le
#  lek
# leka
# ekar
# kar
# ar j
# r ja
#  jaa
# jaay
# aaye
# ayeg
# yega
# ega
#
# ga
# a
# a
# ap
#
# apn
# apna
# pna
# na t
# a ti
#  tim
# time
# ime
# me a
# e aa
#  aay
# aaye
# ayeg
# yega
# ega
#
# ga
# a
# a
# ap
#
# apn
# apna
# pna
# na t
# a ti
#  tim
# time
# ime
# me a
# e aa
#  aay
# aaye
# ayeg
# yega
# ega
#
# ga
# a
# a
# ap
#
# apn
# apna
# pna
# na t
# a ti
#  tim
# time
# ime
# me a
# e aa
#  aay
# aaye
# ayeg
# yega
# ega
#
# ga
# a
# a
# ap
#
# apn
# apna
# pna
# na t
# a ti
#  tim
# time
# ime
# me a
# e aa
#  aay
# aaye
# ayeg
# yega
# ega
#
# ga
# a
# a
# ap
#
# apn
# apna
# pna
# na t
# a ti
#  tim
# time
# ime
# me a
# e aa
#  aay
# aaye
# ayeg
# yega
# ega
#
# ga
# a
# a
# ap
#
# apn
# apna
# pna
# na t
# a ti
#  tim
# time
# ime
# me a
# e aa
#  aay
# aaye
# ayeg
# yega
# ega
#
# ga
# a
# a
# ap
#
# apn
# apna
# pna
# na t
# a ti
#  tim
# time
# ime
# me a
# e aa
#  aay
# aaye
# ayeg
# yega
# ega
#
# ga
# a
# a
# ap
#
# apn
# apna
# pna
# na t
# a ti
#  tim
# time
# ime
# me a
# e aa
#  aay
# aaya
# aya
# ya h
# a ha
#  hai
# hai
#
# ai
# k
# i
# ky
#
# kya
# kya
# ya g
# a gh
#  gha
# ghan
# hant
# anta
# nta
# ta l
# a le
#  lek
# leka
# ekar
# kar
# ar j
# r ja
#  jaa
# jaay
# aaye
# ayeg
# yega
# ega
#
# ga
# a
# a
# ap
#
# apn
# apna
# pna
# na t
# a ti
#  tim
# time
# ime
# me a
# e aa
#  aay
# aaye
# ayeg
# yega
# ega
#
# ga
# a
# a
# ap
#
# apn
# apna
# pna
# na t
# a ti
#  tim
# time
# ime
# me a
# e aa
#  aay
# aaye
# ayeg
# yega
# ega
#
# ga
# a
# a
# ap
#
# apn
# apna
# pna
# na t
# a ti
#  tim
# time
# ime
# me a
# e aa
#  aay
# aaye
# ayeg
# yega
# ega
#
# ga
# a
# a
# ap
#
# apn
# apna
# pna
# na t
# a ti
#  tim
# time
# ime
# me a
# e aa
#  aay
# aaya
# aya
# ya h
# a ha
#  hat
# hath
# ath
# th n
# h na
#  nai
# nai
# ai h
# i ha
#  hai
# hai
#
# ai
# k
# i
# ky
#
# kya
# kya
# ya t
# a tu
#  tu
# tu g
# u gh
#  gha
# ghan
# hant
# anta
# nta
# ta l
# a le
#  lek
# leka
# ekar
# kar
# ar j
# r ja
#  jaa
# jaay
# aaye
# ayeg
# yega
# ega
#
# ga
# a
# a
# ap
#
# apn
# apna
# pna
# na t
# a ti
#  tim
# time
# ime
# me a
# e aa
#  aay
# aaye
# ayeg
# yega
# ega
#
# ga
# a
# a
# ap
#
# apn
# apna
# pna
# na t
# a ti
#  tim
# time
# ime
# me a
# e aa
#  aay
# aaye
# ayeg
# yega
# ega
#
# ga
# a
# a
# ap
#
# apn
# apna
# pna
# na t
# a ti
#  tim
# time
# ime
# me a
# e aa
#  aay
# aaye
# ayeg
# yega
# ega
#
# ga
# a
# a
# ap
#
# apn
# apna
# pna
# na t
# a ti
#  tim
# time
# ime
# me a
# e aa
#  aay
# aaya
# aya
# ya h
# a ha
#  hai
# hai
#
# ai
# k
# i
# ky
#
# kya
# kya
# ya g
# a gh
#  gha
# ghan
# hant
# anta
# nta
# ta l
# a le
#  lek
# leka
# ekar
# kar
# ar j
# r ja
#  jaa
# jaay
# aaye
# ayeg
# yega
# ega
#
# ga
# a
# a
# ap
#
# apn
# apna
# pna
# na t
# a ti
#  tim
# time
# ime
# me a
# e aa
#  aay
# aaye
# ayeg
# yega
# ega
#
# ga
# k
# a
# ky
#
# kya
# kya
# ya t
# a tu
#  tu
# tu g
# u gh
#  gha
# ghan
# hant
# anta
# nta
# ta l
# a le
#  lek
# leka
# ekar
# kar
# ar j
# r ja
#  jaa
# jaay
# aaye
# ayeg
# yega
# ega
#
# ga
# a
# a
# ap
#
# apn
# apna
# pna
# na t
# a ti
#  tim
# time
# ime
# me a
# e aa
#  aay
# aaye
# ayeg
# yega
# ega
#
# ga
# a
# a
# ap
#
# apn
# apna
# pna
# na t
# a ti
#  tim
# time
# ime
# me a
# e aa
#  aay
# aaye
# ayeg
# yega
# ega
#
# ga
# a
# a
# ap
#
# apn
# apna
# pna
# na t
# a ti
#  tim
# time
# ime
# me a
# e aa
#  aay
# aaye
# ayeg
# yega
# ega
#
# ga
# a
# a
# ap
#
# apn
# apna
# pna
# na t
# a ti
#  tim
# time
# ime
# me a
# e aa
#  aay
# aaye
# ayeg
# yega
# ega
#
# ga
# a
# a
# ap
#
# apn
# apna
# pna
# na t
# a ti
#  tim
# time
# ime
# me a
# e aa
#  aay
# aaya
# aya
# ya h
# a ha
#  hai
# hai
#
# ai
# k
# i
# ky
#
# kyo
# kyon
# yon
# on k
# n ki
#  ki
# ki h
# i ha
#  hai
# hai
#
# ai
# k
# i
# ky
#
# kya
# kya
# ya t
# a tu
#  tu
# tu d
# u da
#  daf
# dafn
# afna
# fnay
# naye
# ayeg
# yega
# ega
#
# ga
# a
# a
# ap
#
# apn
# apna
# pna
# na t
# a ti
#  tim
# time
# ime
# me a
# e aa
#  aay
# aaye
# ayeg
# yega
# ega
#
# ga
# a
# a
# ap
#
# apn
# apna
# pna
# na t
# a ti
#  tim
# time
# ime
# me a
# e aa
#  aay
# aaye
# ayeg
# yega
# ega
#
# ga
# a
# a
# ap
#
# apn
# apna
# pna
# na t
# a ti
#  tim
# time
# ime
# me a
# e aa
#  aay
# aaye
# ayeg
# yega
# ega
#
# ga
#
# a
#
#
#
#
# t
#
# tu
#
# tu
# tu n
# u na
#  nan
# nang
# anga
# nga
# ga h
# a hi
#  hi
# hi t
# i to
#  to
# to a
# o aa
#  aay
# aaye
# ayeg
# yega
# ega
#
# ga
# k
# a
# ky
#
# kya
# kya
# ya t
# a tu
#  tu
# tu d
# u da
#  daf
# dafn
# afna
# fnay
# naye
# ayeg
# yega
# ega
#
# ga
# a
# a
# ap
#
# apn
# apna
# pna
# na t
# a ti
#  tim
# time
# ime
# me a
# e aa
#  aay
# aaye
# ayeg
# yega
# ega
#
# ga
# a
# a
# ap
#
# apn
# apna
# pna
# na t
# a ti
#  tim
# time
# ime
# me a
# e aa
#  aay
# aaye
# ayeg
# yega
# ega
#
# ga
# k
# a
# ky
#
# kya
# kya
# ya t
# a tu
#  tu
# tu g
# u gh
#  gha
# ghan
# hant
# anta
# nta
# ta l
# a le
#  lek
# leka
# ekar
# kar
# ar j
# r ja
#  jaa
# jaay
# aaye
# ayeg
# yega
# ega
#
# ga
# a
# a
# ap
#
# apn
# apna
# pna
# na t
# a ti
#  tim
# time
# ime
# me a
# e aa
#  aay
# aaye
# ayeg
# yega
# ega
#
# ga
# a
# a
# ap
#
# apn
# apna
# pna
# na t
# a ti
#  tim
# time
# ime
# me a
# e aa
#  aay
# aaye
# ayeg
# yega
# ega
#
# ga
# k
# a
# ky
#
# kya
# kya
# ya g
# a gh
#  gha
# ghan
# hant
# anta
# nta
# ta l
# a le
#  lek
# leka
# ekar
# kar
# ar j
# r ja
#  jaa
# jaay
# aaye
# ayeg
# yega
# ega
#
# ga
# a
# a
# ap
#
# apn
# apna
# pna
# na t
# a ti
#  tim
# time
# ime
# me a
# e aa
#  aay
# aaye
# ayeg
# yega
# ega
#
# ga
# a
# a
# ap
#
# apn
# apna
# pna
# na t
# a ti
#  tim
# time
# ime
# me a
# e aa
#  aay
# aaye
# ayeg
# yega
# ega
#
# ga
# a
# a
# ap
#
# apn
# apna
# pna
# na t
# a ti
#  tim
# time
# ime
# me a
# e aa
#  aay
# aaye
# ayeg
# yega
# ega
#
# ga
# a
# a
# ap
#
# apn
# apna
# pna
# na t
# a ti
#  tim
# time
# ime
# me a
# e aa
#  aay
# aaye
# ayeg
# yega
# ega
#
# ga
# a
# a
# ap
#
# apn
# apna
# pna
# na t
# a ti
#  tim
# time
# ime
# me a
# e aa
#  aay
# aaye
# ayeg
# yega
# ega
#
# ga
# a
# a
# ap
#
# apn
# apna
# pna
# na t
# a ti
#  tim
# time
# ime
# me a
# e aa
#  aay
# aaye
# ayeg
# yega
# ega
#
# ga
# a
# a
# ap
#
# apn
# apna
# pna
# na t
# a ti
#  tim
# time
# ime
# me a
# e aa
#  aay
# aaye
# ayeg
# yega
# ega
#
# ga
# a
# a
# ap
#
# apn
# apna
# pna
# na t
# a ti
#  tim
# time
# ime
# me a
# e aa
#  aay
# aaye
# ayeg
# yega
# ega
#
# ga
# a
# a
# ap
#
# apn
# apna
# pna
# na t
# a ti
#  tim
# time
# ime
# me a
# e aa
#  aay
# aaye
# ayeg
# yega
# ega
#
# ga
# a
# a
# ap
#
# apn
# apna
# pna
# na t
# a ti
#  tim
# time
# ime
# me a
# e aa
#  aay
# aaye
# ayeg
# yega
# ega
#
# ga
# a
# a
# ap
#
# apn
# apna
# pna
# na t
# a ti
#  tim
# time
# ime
# me a
# e aa
#  aay
# aaye
# ayeg
# yega
# ega
#
# ga
# a
# a
# ap
#
# apn
# apna
# pna
# na t
# a ti
#  tim
# time
# ime
# me a
# e aa
#  aay
# aaye
# ayeg
# yega
# ega
#
# ga
#
# a
#
#
#
#
# t
#
# tu
#
# tu
# tu n
# u na
#  nan
# nang
# anga
# nga
# ga h
# a hi
#  hi
# hi t
# i to
#  to
# to a
# o aa
#  aay
# aaye
# ayeg
# yega
# ega
#
# ga
# a
# a
# ap
#
# apn
# apna
# pna
# na t
# a ti
#  tim
# time
# ime
# me a
# e aa
#  aay
# aaya
# aya
# ya h
# a ha
#  hai
# hai
#
# ai
# k
# i
# ky
#
# kya
# kya
# ya t
# a tu
#  tu
# tu g
# u gh
#  gha
# ghan
# hant
# anta
# nta
# ta l
# a le
#  lek
# leka
# ekar
# kar
# ar j
# r ja
#  jaa
# jaay
# aaye
# ayeg
# yega
# ega
#
# ga
# a
# a
# ap
#
# apn
# apna
# pna
# na t
# a ti
#  tim
# time
# ime
# me a
# e aa
#  aay
# aaye
# ayeg
# yega
# ega
#
# ga
# a
# a
# ap
#
# apn
# apna
# pna
# na t
# a ti
#  tim
# time
# ime
# me a
# e aa
#  aay
# aaye
# ayeg
# yega
# ega
#
# ga
# a
# a
# ap
#
# apn
# apna
# pna
# na t
# a ti
#  tim
# time
# ime
# me a
# e aa
#  aay
# aaye
# ayeg
# yega
# ega
#
# ga
# a
# a
# ap
#
# apn
# apna
# pna
# na t
# a ti
#  tim
# time
# ime
# me a
# e aa
#  aay
# aaye
# ayeg
# yega
# ega
#
# ga
# k
# a
# ky
#
# kya
# kya
# ya t
# a tu
#  tu
# tu d
# u da
#  daf
# dafn
# afna
# fnay
# naye
# ayeg
# yega
# ega
#
# ga
# a
# a
# ap
#
# apn
# apna
# pna
# na t
# a ti
#  tim
# time
# ime
# me a
# e aa
#  aay
# aaye
# ayeg
# yega
# ega
#
# ga
# a
# a
# ap
#
# apn
# apna
# pna
# na t
# a ti
#  tim
# time
# ime
# me a
# e aa
#  aay
# aaye
# ayeg
# yega
# ega
#
# ga
# a
# a
# ap
#
# apn
# apna
# pna
# na t
# a ti
#  tim
# time
# ime
# me a
# e aa
#  aay
# aaye
# ayeg
# yega
# ega
#
# ga
# a
# a
# ap
#
# apn
# apna
# pna
# na t
# a ti
#  tim
# time
# ime
# me a
# e aa
#  aay
# aaye
# ayeg
# yega
# ega
#
# ga
# a
# a
# ap
#
# apn
# apna
# pna
# na t
# a ti
#  tim
# time
# ime
# me a
# e aa
#  aay
# aaye
# ayeg
# yega
# ega
#
# ga
# a
# a
# ap
#
# apn
# apna
# pna
# na t
# a ti
#  tim
# time
# ime
# me a
# e aa
#  aay
# aaye
# ayeg
# yega
# ega
#
# ga
# a
# a
# ap
#
# apn
# apna
# pna
# na t
# a ti
#  tim
# time
# ime
# me a
# e aa
#  aay
# aaye
# ayeg
# yega
# ega
#
# ga
# k
# a
# ky
#
# kya
# kya
# ya g
# a gh
#  gha
# ghan
# hant
# anta
# nta
# ta l
# a le
#  lek
# leka
# ekar
# kar
# ar j
# r ja
#  jaa
# jaay
# aaye
# ayeg
# yega
# ega
#
# ga
# a
# a
# ap
#
# apn
# apna
# pna
# na t
# a ti
#  tim
# time
# ime
# me a
# e aa
#  aay
# aaya
# aya
# ya h
# a ha
#  hai
# hai
#
# ai
# k
# i
# ky
#
# kya
# kya
# ya g
# a gh
#  gha
# ghan
# hant
# anta
# nta
# ta l
# a le
#  lek
# leka
# ekar
# kar
# ar j
# r ja
#  jaa
# jaay
# aaye
# ayeg
# yega
# ega
#
# ga
# a
# a
# ap
#
# apn
# apna
# pna
# na t
# a ti
#  tim
# time
# ime
# me a
# e aa
#  aay
# aaye
# ayeg
# yega
# ega
#
# ga
# k
# a
# ky
#
# kya
# kya
# ya t
# a tu
#  tu
# tu g
# u gh
#  gha
# ghan
# hant
# anta
# nta
# ta l
# a le
#  lek
# leka
# ekar
# kar
# ar j
# r ja
#  jaa
# jaay
# aaye
# ayeg
# yega
# ega
#
# ga
# a
# a
# ap
#
# apn
# apna
# pna
# na t
# a ti
#  tim
# time
# ime
# me a
# e aa
#  aay
# aaye
# ayeg
# yega
# ega
#
# ga
# a
# a
# ap
#
# apn
# apna
# pna
# na t
# a ti
#  tim
# time
# ime
# me a
# e aa
#  aay
# aaya
# aya
# ya h
# a ha
#  hai
# hai
#
# ai
# k
# i
# ky
#
# kya
# kya
# ya t
# a tu
#  tu
# tu g
# u gh
#  gha
# ghan
# hant
# anta
# nta
# ta l
# a le
#  lek
# leka
# ekar
# kar
# ar j
# r ja
#  jaa
# jaay
# aaye
# ayeg
# yega
# ega
#
# ga
#
# a
#
#
#
#
# t
#
# tu
#
# tu
# tu n
# u na
#  nan
# nang
# anga
# nga
# ga h
# a hi
#  hi
# hi t
# i to
#  to
# to a
# o aa
#  aay
# aaya
# aya
# ya h
# a ha
#  hai
# hai
# ai j
# i ja
#  jai
# jais
# aisa
# isa
# sa k
# a ko
#  koy
# koyi
# oyi
# yi h
# i ha
#  hai
# hai
#
# ai
# k
# i
# ky
#
# kya
# kya
# ya g
# a gh
#  gha
# ghan
# hant
# anta
# nta
# ta l
# a le
#  lek
# leka
# ekar
# kar
# ar j
# r ja
#  jaa
# jaay
# aaye
# ayeg
# yega
# ega
#
# ga
# a
# a
# ap
#
# apn
# apna
# pna
# na t
# a ti
#  tim
# time
# ime
# me a
# e aa
#  aay
# aaya
# aya
# ya h
# a ha
#  hat
# hath
# ath
# th n
# h na
#  nah
# nahi
# ahin
# hin
# in h
# n ha
#  hai
# hai
#
# ai
# k
# i
# ky
#
# kya
# kya
# ya t
# a tu
#  tu
# tu g
# u gh
#  gha
# ghan
# hant
# anta
# nta
# ta l
# a le
#  lek
# leka
# ekar
# kar
# ar j
# r ja
#  jaa
# jaay
# aaye
# ayeg
# yega
# ega
#
# ga
# a
# a
# ap
#
# apn
# apna
# pna
# na t
# a ti
#  tim
# time
# ime
# me a
# e aa
#  aay
# aaye
# ayeg
# yega
# ega
#
# ga
# a
# a
# ap
#
# apn
# apna
# pna
# na t
# a ti
#  tim
# time
# ime
# me a
# e aa
#  aay
# aaye
# ayeg
# yega
# ega
#
# ga
#
# a
#
#
#
#
# t
#
# tu
#
# tu
# tu n
# u na
#  nan
# nang
# anga
# nga
# ga h
# a hi
#  hi
# hi t
# i to
#  to
# to a
# o aa
#  aay
# aaye
# ayeg
# yega
# ega
#
# ga
# a
# a
# ap
#
# apn
# apna
# pna
# na t
# a ti
#  tim
# time
# ime
# me a
# e aa
#  aay
# aaye
# ayeg
# yega
# ega
#
# ga
# a
# a
# ap
#
# apn
# apna
# pna
# na t
# a ti
#  tim
# time
# ime
# me a
# e aa
#  aay
# aaye
# ayeg
# yega
# ega
#
# ga
# a
# a
# ap
#
# apn
# apna
# pna
# na t
# a ti
#  tim
# time
# ime
# me a
# e aa
#  aay
# aaye
# ayeg
# yega
# ega
#
# ga
# a
# a
# ap
#
# apn
# apna
# pna
# na t
# a ti
#  tim
# time
# ime
# me a
# e aa
#  aay
# aaya
# aya
# ya h
# a ha
#  hai
# hai
#
# ai
# k
# i
# ky
#
# kya
# kya
# ya g
# a gh
#  gha
# ghan
# hant
# anta
# nta
# ta l
# a le
#  lek
# leka
# ekar
# kar
# ar j
# r ja
#  jaa
# jaay
# aaye
# ayeg
# yega
# ega
#
# ga
# a
# a
# ap
#
# apn
# apna
# pna
# na t
# a ti
#  tim
# time
# ime
# me a
# e aa
#  aay
# aaye
# ayeg
# yega
# ega
#
# ga
# a
# a
# ap
#
# apn
# apna
# pna
# na t
# a ti
#  tim
# time
# ime
# me a
# e aa
#  aay
# aaye
# ayeg
# yega
# ega
#
# ga
# a
# a
# ap
#
# apn
# apna
# pna
# na t
# a ti
#  tim
# time
# ime
# me a
# e aa
#  aay
# aaye
# ayeg
# yega
# ega
#
# ga
# a
# a
# ap
#
# apn
# apna
# pna
# na t
# a ti
#  tim
# time
# ime
# me a
# e aa
#  aay
# aaye
# ayeg
# yega
# ega
#
# ga
# a
# a
# ap
#
# apn
# apna
# pna
# na t
# a ti
#  tim
# time
# ime
# me a
# e aa
#  aay
# aaye
# ayeg
# yega
# ega
#
# ga
# k
# a
# ky
#
# kya
# kya
# ya t
# a tu
#  tu
# tu g
# u gh
#  gha

# %%
print(len(output))
# Out:
# 2004

# %%
with open('output.txt','w') as f:
    f.write(output)
    f.close()

# %%
with open('output.txt','r') as f:
    s = f.read()
    print(len(s))
# Out:
# 2004
